# %% [markdown]
# REEMBOLSOS DOS PARLAMENTARES DA BAHIA
# ======================================
#
# Este repositório possui os reembolsos de todos os deputados federais da Bahia de todos os partidos durante os anos de 2009 a 2017.
#
# Os dados foram disponibilizados pela **OPERAÇÃO SERENATA DE AMOR**.
#
# O que você verá
# -----------------

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
# Importing the dataset
dataset = pd.read_csv('TodosReembolsosBahia.csv', encoding='latin1')
print(len(dataset)) #118796 linhas
dataset.head()
# Out:
# 118796
# /Users/lucasrcsantana/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Ano  CódigoCandidato  CódigoDocumento  ValorTotalLiquido CódigoReembolso  \
# 0  2009             1063          1570103              800.0            2894
# 1  2009             1063          1570107              430.0            2894
# 2  2009             1063          1570118             4195.0            2894
# 3  2009             1063          1570121             3970.0            2894
# 4  2009             1063          1583550              800.0            2912
#
#   NomeParlamentar  DocumentoDoParlamentar  DocumentoParlamentar  Mandato  \
# 0       JOÃO LEÃO                 74550.0                 199.0   2011.0
# 1       JOÃO LEÃO                 74550.0                 199.0   2011.0
# 2       JOÃO LEÃO                 74550.0                 199.0   2011.0
# 3       JOÃO LEÃO                 74550.0                 199.0   2011.0
# 4       JOÃO LEÃO                 74550.0                 199.0   2011.0
#
#   Estado     ...     TipoDocumento   DataEmissão  ValorDocumento  \
# 0     BA     ...                 1   Mar 6, 2009           800.0
# 1     BA     ...                 1   Mar 6, 2009           430.0
# 2     BA     ...                 0  Apr 13, 2009          4195.0
# 3     BA     ...                 0  Apr 13, 2009          3970.0
# 4     BA     ...                 1   Apr 8, 2009           800.0
#
#   ValorRemarcado  ValorLíquidoReembolso Mês Parcelado  Passageiro  \
# 0            0.0                  800.0   3         0         NaN
# 1            0.0                  430.0   3         0         NaN
# 2            0.0                 4195.0   4         0         NaN
# 3            0.0                 3970.0   4         0         NaN
# 4            0.0                  800.0   4         0         NaN
#
#   PercursoViagem  NúmeroLote
# 0            NaN      390844
# 1            NaN      390844
# 2            NaN      390853
# 3            NaN      390852
# 4            NaN      395314
#
# [5 rows x 29 columns]

# %%
#RETIRANDO COlUNAS JULGADAS DESNECESSÁRIAS
dataset = dataset.drop('NúmeroDocumento',axis = 1)
dataset = dataset.drop('cnpj_cpf',axis = 1)
dataset = dataset.drop('CódigoMandato',axis = 1)
dataset = dataset.drop('CódigoDocumento',axis = 1)
dataset = dataset.drop('CódigoReembolso',axis = 1)
dataset = dataset.drop('DocumentoDoParlamentar',axis = 1)
dataset = dataset.drop('DocumentoParlamentar',axis = 1)
dataset = dataset.drop('CódigoCandidato',axis = 1)
dataset = dataset.drop('NúmeroLote',axis = 1)
dataset.head()
# Out:
#     Ano  ValorTotalLiquido NomeParlamentar  Mandato Estado Partido  \
# 0  2009              800.0       JOÃO LEÃO   2011.0     BA      PP
# 1  2009              430.0       JOÃO LEÃO   2011.0     BA      PP
# 2  2009             4195.0       JOÃO LEÃO   2011.0     BA      PP
# 3  2009             3970.0       JOÃO LEÃO   2011.0     BA      PP
# 4  2009              800.0       JOÃO LEÃO   2011.0     BA      PP
#
#    NúmeroSubquota                                  DescriçãoSubquota  \
# 0               1  Maintenance of office supporting parliamentary...
# 1               1  Maintenance of office supporting parliamentary...
# 2               5                Publicity of parliamentary activity
# 3               3                               Fuels and lubricants
# 4               1  Maintenance of office supporting parliamentary...
#
#    CódigoSubquota DescriçãoGrupoSubquota  \
# 0               0                    NaN
# 1               0                    NaN
# 2               0                    NaN
# 3               4     Sem especificações
# 4               0                    NaN
#
#                                           Fornecedor  TipoDocumento  \
# 0                   MARCÍLIO BARRETO MARQUES ALMEIDA              1
# 1                          OSVALDO ORNELLAS MENDONÇA              1
# 2  LAYOUT EDITORA, GRÁFICA, PUBLICIDADE E COMUNIC...              0
# 3            POSTO DE COMBUSTÍVEIS VERDES MARES LTDA              0
# 4                   MARCÍLIO BARRETO MARQUES ALMEIDA              1
#
#     DataEmissão  ValorDocumento  ValorRemarcado  ValorLíquidoReembolso  Mês  \
# 0   Mar 6, 2009           800.0             0.0                  800.0    3
# 1   Mar 6, 2009           430.0             0.0                  430.0    3
# 2  Apr 13, 2009          4195.0             0.0                 4195.0    4
# 3  Apr 13, 2009          3970.0             0.0                 3970.0    4
# 4   Apr 8, 2009           800.0             0.0                  800.0    4
#
#    Parcelado Passageiro PercursoViagem
# 0          0        NaN            NaN
# 1          0        NaN            NaN
# 2          0        NaN            NaN
# 3          0        NaN            NaN
# 4          0        NaN            NaN

# %%
#CATEGORIZANDO AS COLUNAS QUE SERVIRÃO DE VARIÁVEIS INDEPENDENTES PARA OS GRÁFICOS
dataset.Ano = dataset.Ano.astype('category')
dataset.NomeParlamentar = dataset.NomeParlamentar.astype('category')
dataset.Fornecedor = dataset.Fornecedor.astype('category')
dataset.Mandato = dataset.Mandato.astype('category')
dataset.NúmeroSubquota = dataset.NúmeroSubquota.astype('category')
dataset.DescriçãoSubquota = dataset.DescriçãoSubquota.astype('category')
dataset.DescriçãoGrupoSubquota = dataset.DescriçãoGrupoSubquota.astype('category')
dataset.Estado = dataset.Estado.astype('category')
dataset.Partido = dataset.Partido.astype('category')
dataset.CódigoSubquota = dataset.CódigoSubquota.astype('category')
dataset.TipoDocumento = dataset.TipoDocumento.astype('category')
dataset.Mês = dataset.Mês.astype('category')
dataset.Passageiro = dataset.Passageiro.astype('category')
dataset.PercursoViagem = dataset.PercursoViagem.astype('category')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118796 entries, 0 to 118795
# Data columns (total 20 columns):
# Ano                       118796 non-null category
# ValorTotalLiquido         118796 non-null float64
# NomeParlamentar           118796 non-null category
# Mandato                   118796 non-null category
# Estado                    118796 non-null category
# Partido                   118796 non-null category
# NúmeroSubquota            118796 non-null category
# DescriçãoSubquota         118796 non-null category
# CódigoSubquota            118796 non-null category
# DescriçãoGrupoSubquota    56823 non-null category
# Fornecedor                118796 non-null category
# TipoDocumento             118796 non-null category
# DataEmissão               118796 non-null object
# ValorDocumento            118796 non-null float64
# ValorRemarcado            118796 non-null float64
# ValorLíquidoReembolso     118796 non-null float64
# Mês                       118796 non-null category
# Parcelado                 118796 non-null int64
# Passageiro                525 non-null category
# PercursoViagem            1698 non-null category
# dtypes: category(14), float64(4), int64(1), object(1)
# memory usage: 8.1+ MB

# %%
dataset.describe()
# Out:
#        ValorTotalLiquido  ValorDocumento  ValorRemarcado  \
# count      118796.000000   118796.000000   118796.000000
# mean          716.359236      729.020973       12.034509
# std          2496.521316     2524.774696      197.566927
# min             0.010000        0.090000        0.000000
# 25%            51.360000       52.830000        0.000000
# 50%           113.000000      114.200000        0.000000
# 75%           245.595000      250.000000        0.000000
# max        140000.000000   140000.000000    21118.100000
#
#        ValorLíquidoReembolso      Parcelado
# count          118796.000000  118796.000000
# mean              711.983329       0.000219
# std              2477.350104       0.014792
# min                 0.010000       0.000000
# 25%                51.300000       0.000000
# 50%               113.000000       0.000000
# 75%               245.012500       0.000000
# max            140000.000000       1.000000

# %%
#FAZENDO LISTAS E DICIONÁRIOS QUE PODEM SER NECESSÁRIOS DEPOIS
Anos = list(dataset.Ano.cat.categories)
Partidos = list(dataset.Partido.cat.categories)
Parlamentares = list(dataset.NomeParlamentar.cat.categories)
PartidoDict = {'DEM': 1, 'PCdoB': 2, 'PDT': 3, 'PEN': 4, 'PHS': 5, 'PMDB': 6, 'PP': 7, 'PPS': 8, 'PR': 9, 'PRB': 10, 'PROS': 11, 'PRP': 12, 'PSB': 13, 'PSC': 14, 'PSD': 15, 'PSDB': 16, 'PT': 17, 'PTB': 18, 'PTN': 19, 'PV': 20, 'SD': 21}
AnoDict = {'2009': 1 , '2010': 2 , '2011': 3, '2012': 4, '2013': 5, '2014': 6, '2015':7 , '2016': 8, '2017': 9}

# %% [markdown]
# Os maiores valores de reembolsos únicos foram os seguintes
# ---

# %%
#DATASET ORGANIZADO PELOS MAIORES VALORES DE REEMBOLSO
dataset.sort_values(by='ValorLíquidoReembolso', ascending=False).head(50)
# Out:
#          Ano  ValorTotalLiquido        NomeParlamentar Mandato Estado Partido  \
# 82971   2014           140000.0  FÉLIX MENDONÇA JÚNIOR  2015.0     BA     PDT
# 21905   2010           114931.0    FERNANDO DE FABINHO  2007.0     BA     DEM
# 94330   2015           100000.0  FÉLIX MENDONÇA JÚNIOR  2015.0     BA     PDT
# 109028  2016            95000.0  FÉLIX MENDONÇA JÚNIOR  2015.0     BA     PDT
# 83430   2014            92266.0        FERNANDO TORRES  2015.0     BA     PSD
# 108873  2016            90000.0  FÉLIX MENDONÇA JÚNIOR  2015.0     BA     PDT
# 95240   2015            80300.0      LUCIO VIEIRA LIMA  2015.0     BA    PMDB
# 85838   2014            74800.0      LUCIO VIEIRA LIMA  2015.0     BA    PMDB
# 94185   2015            74000.0  FÉLIX MENDONÇA JÚNIOR  2015.0     BA     PDT
# 80308   2014            70400.0         ROBERTO BRITTO  2015.0     BA      PP
# 80288   2014            70000.0         ROBERTO BRITTO  2015.0     BA      PP
# 58176   2012            70000.0      LUCIO VIEIRA LIMA  2015.0     BA    PMDB
# 83430               5       Publicity of parliamentary activity
# 108873              5       Publicity of parliamentary activity
# 95240               5       Publicity of parliamentary activity
# 85838               5       Publicity of parliamentary activity
# 94185               5       Publicity of parliamentary activity
# 80308               5       Publicity of parliamentary activity
# 80288               5       Publicity of parliamentary activity
# 58176               5       Publicity of parliamentary activity
# 95239               4  Consultancy, research and technical work
# 75889               5       Publicity of parliamentary activity
# 107276              5       Publicity of parliamentary activity
# 52083               5       Publicity of parliamentary activity
# 85839               4  Consultancy, research and technical work
# 85837               4  Consultancy, research and technical work
# 93610               5       Publicity of parliamentary activity
# 97711               5       Publicity of parliamentary activity
# 72230               5       Publicity of parliamentary activity
# 109263              5       Publicity of parliamentary activity
# 94557               5       Publicity of parliamentary activity
# 16530               5       Publicity of parliamentary activity
# 58177               5       Publicity of parliamentary activity
# 113912              5       Publicity of parliamentary activity
# 67022               5       Publicity of parliamentary activity
# 88092               5       Publicity of parliamentary activity
# 80221               5       Publicity of parliamentary activity
# 34717               5       Publicity of parliamentary activity
# 80255               5       Publicity of parliamentary activity
# 90838               5       Publicity of parliamentary activity
# 105681              5       Publicity of parliamentary activity
# 105495              5       Publicity of parliamentary activity
# 6509                5       Publicity of parliamentary activity
# 55794               5       Publicity of parliamentary activity
# 85842             119   Aircraft renting or charter of aircraft
# 42822               5       Publicity of parliamentary activity
# 77928               5       Publicity of parliamentary activity
# 53078               5       Publicity of parliamentary activity
# 109252              5       Publicity of parliamentary activity
# 104680              4  Consultancy, research and technical work
# 52081               5       Publicity of parliamentary activity
# 34774               5       Publicity of parliamentary activity
# 88436               4  Consultancy, research and technical work
# 107116              5       Publicity of parliamentary activity
# 88444               4  Consultancy, research and technical work
# 104641              4  Consultancy, research and technical work
# 52082               5       Publicity of parliamentary activity
# 66979               5       Publicity of parliamentary activity
#
#        CódigoSubquota DescriçãoGrupoSubquota  \
# 82971               0                    NaN
# 21905               0                    NaN
# 94330               0                    NaN
# 109028              0                    NaN
# 83430               0                    NaN
# 108873              0                    NaN
# 95240               0                    NaN
# 85838               0                    NaN
# 94185               0                    NaN
# 80308               0                    NaN
# 80288               0                    NaN
# 58176               0                    NaN
# 95239               0                    NaN
# 75889               0                    NaN
# 107276              0                    NaN
# 52083               0                    NaN
# 85839               0                    NaN
# 85837               0                    NaN
# 93610               0                    NaN
# 97711               0                    NaN
# 72230               0                    NaN
# 109263              0                    NaN
# 94557               0                    NaN
# 16530               0                    NaN
# 58177               0                    NaN
# 113912              0                    NaN
# 67022               0                    NaN
# 88092               0                    NaN
# 80221               0                    NaN
# 34717               0                    NaN
# 80255               0                    NaN
# 90838               0                    NaN
# 105681              0                    NaN
# 105495              0                    NaN
# 6509                0                    NaN
# 55794               0                    NaN
# 85842               0                    NaN
# 42822               0                    NaN
# 77928               0                    NaN
# 53078               0                    NaN
# 109252              0                    NaN
# 104680              0                    NaN
# 52081               0                    NaN
# 34774               0                    NaN
# 88436               0                    NaN
# 107116              0                    NaN
# 88444               0                    NaN
# 104641              0                    NaN
# 52082               0                    NaN
# 52082    Nov 5, 2012         40000.0            0.00                40000.0
# 66979   Sep 24, 2013         40000.0            0.00                40000.0
#
#        Mês  Parcelado Passageiro PercursoViagem
# 82971   11          0        NaN            NaN
# 21905   11          0        NaN            NaN
# 94330   11          0        NaN            NaN
# 109028  11          0        NaN            NaN
# 83430   12          0        NaN            NaN
# 108873   5          0        NaN            NaN
# 95240   12          0        NaN            NaN
# 85838   12          0        NaN            NaN
# 94185    6          0        NaN            NaN
# 80308   12          0        NaN            NaN
# 80288   10          0        NaN            NaN
# 58176   12          0        NaN            NaN
# 95239   12          0        NaN            NaN
# 75889   12          0        NaN            NaN
# 107276  11          0        NaN            NaN
# 52083   12          0        NaN            NaN
# 85839   12          0        NaN            NaN
# 85837   12          0        NaN            NaN
# 93610   11          0        NaN            NaN
# 97711   12          0        NaN            NaN
# 72230   12          0        NaN            NaN
# 109263  12          0        NaN            NaN
# 94557   12          0        NaN            NaN
# 16530   12          0        NaN            NaN
# 58177   12          0        NaN            NaN
# 113912   3          0        NaN            NaN
# 67022   12          0        NaN            NaN
# 88092   12          0        NaN            NaN
# 80221    3          0        NaN            NaN
# 34717    6          0        NaN            NaN
# 80255    5          0        NaN            NaN
# 90838   12          0        NaN            NaN
# 105681  12          0        NaN            NaN
# 105495   4          0        NaN            NaN
# 6509     7          0        NaN            NaN
# 55794    8          0        NaN            NaN
# 85842   12          0        NaN            NaN
# 42822   12          0        NaN            NaN
# 77928   12          0        NaN            NaN
# 53078   11          0        NaN            NaN
# 109252  12          0        NaN            NaN
# 104680   7          0        NaN            NaN
# 52081   11          0        NaN            NaN
# 34774    9          0        NaN            NaN
# 88436    7          0        NaN            NaN
# 107116   2          0        NaN            NaN
# 88444    9          0        NaN            NaN
# 104641   5          0        NaN            NaN
# 52082   10          0        NaN            NaN
# 66979    9          0        NaN            NaN

# %%
maxPartido = dataset.Partido[dataset.ValorLíquidoReembolso.argmax]
maxParlamentar = dataset.NomeParlamentar[dataset.ValorLíquidoReembolso.idxmax]
maxAno = dataset.Ano[dataset.ValorLíquidoReembolso.idxmax(j)]
maxValor = dataset.ValorLíquidoReembolso[dataset.ValorLíquidoReembolso.idxmax]
maxDescricao = dataset.DescriçãoSubquota[dataset.ValorLíquidoReembolso.idxmax]
print("O maior reembolso foi realizado para {} do {} em {} no valor de R$ {} com a descrição de {}".format(maxParlamentar, maxPartido, maxAno, maxValor, maxDescricao))
#print('O maior reembolso foi realizado em' + maxAno + ' para ' + maxParlamentar + ' do ' + maxPartido )
# Out:
# O maior reembolso foi realizado para FÉLIX MENDONÇA JÚNIOR do PDT em 2014 no valor de R$ 140000.0 com a descrição de Publicity of parliamentary activity

# %%
Partidos = list(dataset.Partido.cat.categories)
ReembolsoPartido = []
for partido in Partidos:
    reembolsado = dataset.ValorLíquidoReembolso[dataset.Partido == partido].sum()/1000000
    ReembolsoPartido.append(reembolsado)
    print('O valor reembolsado para o {} foi de R$ {} milhões'.format(partido, round(reembolsado,3)))
ReembolsoPartido = np.array(ReembolsoPartido)

plt.figure(figsize=(12, 6))
partReembolso = sns.barplot(x = Partidos, y = dataset.groupby(['Partido'])['ValorLíquidoReembolso'].sum()/1000000)
partReembolso.set_xticklabels(rotation=90, labels=Partidos)
plt.axhline(ReembolsoPartido.mean(), ls='--')
plt.axhline(np.median(ReembolsoPartido), ls='--', color='red')
plt.ylabel('Valor Reembolsado em R$ milhões')
plt.title('Valor Reembolsado por Partido')
plt.show()
# Out:
# O valor reembolsado para o DEM foi de R$ 9.997 milhões
# O valor reembolsado para o PCdoB foi de R$ 4.396 milhões
# O valor reembolsado para o PDT foi de R$ 2.976 milhões
# O valor reembolsado para o PEN foi de R$ 1.518 milhões
# O valor reembolsado para o PHS foi de R$ 0.266 milhões
# O valor reembolsado para o PMDB foi de R$ 3.881 milhões
# O valor reembolsado para o PP foi de R$ 6.318 milhões
# O valor reembolsado para o PPS foi de R$ 1.602 milhões
# O valor reembolsado para o PR foi de R$ 7.187 milhões
# O valor reembolsado para o PRB foi de R$ 4.265 milhões
# O valor reembolsado para o PROS foi de R$ 1.104 milhões
# O valor reembolsado para o PRP foi de R$ 1.197 milhões
# O valor reembolsado para o PSB foi de R$ 1.605 milhões
# O valor reembolsado para o PSC foi de R$ 0.667 milhões
# O valor reembolsado para o PSD foi de R$ 10.818 milhões
# O valor reembolsado para o PSDB foi de R$ 4.963 milhões
# O valor reembolsado para o PT foi de R$ 16.082 milhões
# O valor reembolsado para o PTB foi de R$ 0.77 milhões
# O valor reembolsado para o PTN foi de R$ 0.731 milhões
# O valor reembolsado para o PV foi de R$ 1.667 milhões
# O valor reembolsado para o SD foi de R$ 2.572 milhões

# %%
Parlamentares = list(dataset.NomeParlamentar.cat.categories)
ReembolsoParlamentar = []
PartidoDoParlamentar = []
for parlamentar in Parlamentares:
    reembolsado = dataset.ValorLíquidoReembolso[dataset.NomeParlamentar == parlamentar].sum()/1000000
    partido = dataset.Partido[dataset.NomeParlamentar == parlamentar]
    ReembolsoParlamentar.append(reembolsado)
    #PartidoDoParlamentar.append(partido)
    print('O valor reembolsado para {} foi de R$ {} milhões'.format(parlamentar, round(reembolsado,3)))
ReembolsoParlamentar = np.array(ReembolsoParlamentar)

plt.figure(figsize=(16, 6))
parlReembolso = sns.barplot(x = Parlamentares, y = ReembolsoParlamentar)
parlReembolso.set_xticklabels(rotation=90, labels=Parlamentares)
plt.axhline(ReembolsoParlamentar.mean(), ls='--')
plt.axhline(np.median(ReembolsoParlamentar), ls='--', color='red')
plt.ylabel('Valor Reembolsado em R$ milhões')
plt.title('Reembolso por Parlamentar')
plt.show()
# Out:
# O valor reembolsado para ACELINO POPÓ foi de R$ 1.129 milhões
# O valor reembolsado para AFONSO FLORENCE foi de R$ 1.526 milhões
# O valor reembolsado para ALICE PORTUGAL foi de R$ 1.894 milhões
# O valor reembolsado para AMAURI TEIXEIRA foi de R$ 0.764 milhões
# O valor reembolsado para ANTONIO BRITO foi de R$ 1.204 milhões
# O valor reembolsado para ANTONIO CARLOS MAGALHÃES NETO foi de R$ 1.124 milhões
# O valor reembolsado para LUIZ ARGÔLO foi de R$ 0.927 milhões
# O valor reembolsado para LUIZ BASSUMA foi de R$ 0.467 milhões
# O valor reembolsado para LUIZ CARREIRA foi de R$ 0.379 milhões
# O valor reembolsado para LUIZ DE DEUS foi de R$ 0.671 milhões
# O valor reembolsado para LÍDICE DA MATA foi de R$ 0.522 milhões
# O valor reembolsado para MARCELO GUIMARÃES FILHO foi de R$ 0.597 milhões
# O valor reembolsado para MARCOS MEDRADO foi de R$ 1.645 milhões
# O valor reembolsado para MAURÍCIO TRINDADE foi de R$ 1.104 milhões
# O valor reembolsado para MILTON BARBOSA foi de R$ 0.111 milhões
# O valor reembolsado para MOEMA GRAMACHO foi de R$ 0.725 milhões
# O valor reembolsado para MÁRCIO MARINHO foi de R$ 2.249 milhões
# O valor reembolsado para MÁRIO NEGROMONTE foi de R$ 0.981 milhões
# O valor reembolsado para MÁRIO NEGROMONTE JR. foi de R$ 0.791 milhões
# O valor reembolsado para NELSON PELLEGRINO foi de R$ 1.387 milhões
# O valor reembolsado para OZIEL OLIVEIRA foi de R$ 1.133 milhões
# O valor reembolsado para PASTOR LUCIANO BRAGA foi de R$ 0.154 milhões
# O valor reembolsado para PAULO AZI foi de R$ 0.751 milhões
# O valor reembolsado para PAULO MAGALHÃES foi de R$ 2.411 milhões
# O valor reembolsado para ROBERTO BRITTO foi de R$ 1.906 milhões
# O valor reembolsado para ROBINSON ALMEIDA foi de R$ 0.0 milhões
# O valor reembolsado para RONALDO CARLETTO foi de R$ 0.698 milhões
# O valor reembolsado para RUI COSTA foi de R$ 0.24 milhões
# O valor reembolsado para SEVERIANO ALVES foi de R$ 0.474 milhões
# O valor reembolsado para SÉRGIO BARRADAS CARNEIRO foi de R$ 0.535 milhões
# O valor reembolsado para SÉRGIO BRITO foi de R$ 1.888 milhões
# O valor reembolsado para TIA ERON foi de R$ 0.734 milhões
# O valor reembolsado para TONHA MAGALHÃES foi de R$ 0.489 milhões
# O valor reembolsado para ULDURICO JUNIOR foi de R$ 0.758 milhões
# O valor reembolsado para ULDURICO PINTO foi de R$ 0.266 milhões
# O valor reembolsado para VALMIR ASSUNÇÃO foi de R$ 1.562 milhões
# O valor reembolsado para VELOSO foi de R$ 0.494 milhões
# O valor reembolsado para WALDENOR PEREIRA foi de R$ 1.82 milhões
# O valor reembolsado para WALTER PINHEIRO foi de R$ 0.148 milhões
# O valor reembolsado para ZE CARLOS DA PESCA foi de R$ 0.016 milhões
# O valor reembolsado para ZEZÉU RIBEIRO foi de R$ 0.9 milhões

# %%
ReembolsoAnos = []
for ano in Anos:
    reembolsado = dataset.ValorLíquidoReembolso[dataset.Ano == ano].sum()/1000000
    ReembolsoAnos.append(reembolsado)
    print('O valor reembolsado para o {} foi de R$ {} milhões'.format(ano, round(reembolsado,3)))
ReembolsoAnos = np.array(ReembolsoAnos)

plt.figure(figsize=(12, 6))
partReembolso = sns.barplot(x = dataset.Ano.cat.categories, y = dataset.groupby(['Ano'])['ValorLíquidoReembolso'].sum()/1000000)
partReembolso.set_xticklabels(rotation=90, labels=dataset.Ano)
plt.axhline(ReembolsoAnos.mean(), ls='--')
plt.axhline(np.median(ReembolsoAnos), ls='--', color='red')
plt.ylabel('Valor Reembolsado em R$ milhões')
plt.title('Valor Reembolsado por Ano')
plt.show()
# Out:
# O valor reembolsado para o 2009 foi de R$ 7.128 milhões
# O valor reembolsado para o 2010 foi de R$ 9.436 milhões
# O valor reembolsado para o 2011 foi de R$ 9.832 milhões
# O valor reembolsado para o 2012 foi de R$ 9.816 milhões
# O valor reembolsado para o 2013 foi de R$ 10.38 milhões
# O valor reembolsado para o 2014 foi de R$ 11.117 milhões
# O valor reembolsado para o 2015 foi de R$ 12.562 milhões
# O valor reembolsado para o 2016 foi de R$ 13.122 milhões
# O valor reembolsado para o 2017 foi de R$ 1.188 milhões

# %%
f , axes = plt.subplots(1,3, figsize = (16,5))
plt.figure(figsize=(16, 6))
documentoReembolso = sns.boxplot(x = dataset.TipoDocumento, y = dataset.ValorLíquidoReembolso, showfliers=False, ax=axes[0])
documentoReembolso2 = sns.boxplot(x = dataset.TipoDocumento, y = dataset.ValorLíquidoReembolso, ax=axes[1])
documentoReembolso3 = sns.barplot(data=dataset, x = 'TipoDocumento', y = 'ValorLíquidoReembolso', ax=axes[2])
documentoReembolso.set_xticklabels(rotation=90, labels=dataset.TipoDocumento.cat.categories)
documentoReembolso2.set_xticklabels(rotation=90, labels=dataset.TipoDocumento.cat.categories)
#plt.axhline(dataset.ValorLíquidoReembolso.mean(), ls='--')
#plt.axhline(np.median(dataset.ValorLíquidoReembolso), ls='--', color='red')
plt.show()

TiposDeDocumento = list(dataset.TipoDocumento.cat.categories)
ReembolsoDocumento = []
for documento in TiposDeDocumento:
    reembolsado = dataset.ValorLíquidoReembolso[dataset.TipoDocumento == documento].sum()/1000000
    ReembolsoDocumento.append(reembolsado)
    print('O valor reembolsado para o tipo {} foi de R$ {} milhões'.format(documento, round(reembolsado,3)))
ReembolsoDocumento = np.array(ReembolsoDocumento)
# Out:
# O valor reembolsado para o tipo 0 foi de R$ 74.303 milhões
# O valor reembolsado para o tipo 1 foi de R$ 10.182 milhões
# O valor reembolsado para o tipo 2 foi de R$ 0.075 milhões
# O valor reembolsado para o tipo 3 foi de R$ 0.021 milhões

# %%
f , axes = plt.subplots(1,2, figsize = (16,5))
vis = sns.boxplot(data=dataset, x='Partido', y='ValorLíquidoReembolso', showfliers=False, ax=axes[0])
vis2 = sns.boxplot(data=dataset, x='Partido', y='ValorLíquidoReembolso', ax=axes[1])
vis.set_xticklabels(rotation=90, labels=dataset.Partido.cat.categories)
vis2.set_xticklabels(rotation=90, labels=dataset.Partido.cat.categories)
plt.show()

# %%
vis4 = sns.distplot(ReembolsoPartido,bins=20, kde=False)

# %%
#INSPEÇÃO POR PARLAMENTAR
#ESSA FUNÇÃO INSPECIONA OS REEMBOLSOS DE APENAS UM DEPUTADO POR UMA OU MAIS DETERMINADAS CARACTERÍSTICAS COMO 'DescriçãoSubquota', 'Ano' e 'TipoDocumento'
# InspecaoPorParlamentar (nome='ALICE PORTUGAL', feature ='DescriçãoSubquota')
def InspecaoPorParlamentar (nome='ACELINO POPÓ', feature = 'DescriçãoSubquota'):
    dataParlamentar = dataset.groupby(['NomeParlamentar',feature])['ValorLíquidoReembolso'].sum().to_frame(name='ValorLíquidoReembolso').reset_index().sort_values(by='ValorLíquidoReembolso', ascending = False)
    dataParlamentar = dataParlamentar[dataParlamentar.NomeParlamentar == nome]
    dataParlamentar[feature] = dataParlamentar[feature].cat.remove_unused_categories()
    
    plt.figure(figsize=(16, 5))
    g = sns.barplot(data = dataParlamentar, x= feature, y ='ValorLíquidoReembolso')
    g.set(ylabel='Valor Líquido Reembolsado')
    g.set_xticklabels(rotation=90, labels=dataParlamentar[feature].cat.categories)
    plt.show()
    return dataParlamentar
 
    
InspecaoPorParlamentar('ALICE PORTUGAL')
# Out:
#    NomeParlamentar                                  DescriçãoSubquota  \
# 35  ALICE PORTUGAL                Publicity of parliamentary activity
# 33  ALICE PORTUGAL  Maintenance of office supporting parliamentary...
# 28  ALICE PORTUGAL   Automotive vehicle renting or watercraft charter
# 30  ALICE PORTUGAL                               Fuels and lubricants
# 37  ALICE PORTUGAL                                  Telecommunication
# 27  ALICE PORTUGAL              Automotive vehicle renting or charter
# 31  ALICE PORTUGAL                       Locomotion, meal and lodging
# 32  ALICE PORTUGAL  Lodging, except for congressperson from Distri...
# 29  ALICE PORTUGAL                                Congressperson meal
# 38  ALICE PORTUGAL          Terrestrial, maritime and fluvial tickets
# 36  ALICE PORTUGAL                             Taxi, toll and parking
# 34  ALICE PORTUGAL                          Publication subscriptions
#
#     ValorLíquidoReembolso
# 35              786931.58
# 33              335893.78
# 28              273924.00
# 30              226912.28
# 37              119491.01
# 27              109069.39
# 31               15232.50
# 32               13532.90
# 29               11579.73
# 38                 597.75
# 36                 434.97
# 34                 110.00

# %%
#INSPEÇÃO POR COLUNA - CASO GENÉRICO DA ANTERIOR
#ESSA FUNÇÃO INSPECIONA OS REEMBOLSOS DOS DEPUTADOS POR UMA OU MAIS DETERMINADAS CARACTERÍSTICAS COMO 'DescriçãoSubquota', 'Ano' e 'TipoDocumento'
# InspecaoPorParlamentar (coluna = 'NomeParlamentar', ordem='ValorLíquidoReembolso')
def InspecaoPorColuna (coluna = 'NomeParlamentar', ordem='ValorLíquidoReembolso'):
    b = dataset.groupby(coluna)['ValorLíquidoReembolso'].sum().to_frame(name='ValorLíquidoReembolso').reset_index().sort_values(by=ordem, ascending = False)
    f , axes = plt.subplots(1, len(coluna), figsize = (16,5))
    
    
    for j in range(len(coluna)):
        if len(coluna)==1:
            k = None
        else:
            k=axes[j] 
        c = dataset.groupby(coluna[j])['ValorLíquidoReembolso'].sum().reset_index()
        visColunas = sns.barplot(x= coluna[j], y='ValorLíquidoReembolso', data = c, ax=k)
        visColunas.set(ylabel='Valor Líquido Reembolsado')
        visColunas.set_xticklabels(rotation=90, labels=c[coluna[j]].cat.categories)
    plt.show()
    return b

# PARA MAIS DE UMA CARACTERÍSTICA PASSE UMA LISTA COMO ARGUMENTO
# InspecaoPorParlamentar (nome='ALICE PORTUGAL', feature =['Partido','Ano'])
InspecaoPorColuna(['NomeParlamentar'])
# Out:
#              NomeParlamentar  ValorLíquidoReembolso
# 65           PAULO MAGALHÃES             2410509.82
# 37        JOSÉ CARLOS ARAÚJO             2395607.83
# 24           FERNANDO TORRES             2326494.62
# 41       JOÃO CARLOS BACELAR             2258082.55
# 58            MÁRCIO MARINHO             2248720.77
# 44             JUTAHY JUNIOR             2204401.64
# 39                JOSÉ ROCHA             2044008.48
# 13            CLAUDIO CAJADO             1958007.64
# 15            DANIEL ALMEIDA             1913045.67
# 66            ROBERTO BRITTO             1906076.58
# 2             ALICE PORTUGAL             1893709.89
# 72              SÉRGIO BRITO             1888042.27
# 27     FÉLIX MENDONÇA JÚNIOR             1843168.72
# 38                JOSÉ NUNES             1829454.52
# 79          WALDENOR PEREIRA             1819904.89
# 25               FÁBIO SOUTO             1781720.01
# 6          ANTONIO IMBASSAHY             1741824.40
# 54            MARCOS MEDRADO             1645046.13
# 47              LUIZ ALBERTO             1635149.27
# 7       ARTHUR OLIVEIRA MAIA             1601887.97
# 46         LUCIO VIEIRA LIMA             1585628.50
# 29            GERALDO SIMÕES             1565758.50
# 77           VALMIR ASSUNÇÃO             1561662.39
# 1            AFONSO FLORENCE             1525643.01
# 22         ERIVELTON SANTANA             1518230.49
# 61         NELSON PELLEGRINO             1387274.59
# 4              ANTONIO BRITO             1203892.83
# 45               JÂNIO NATAL             1196917.14
# 36       JOSÉ CARLOS ALELUIA             1191647.78
# 19             EDSON PIMENTA             1159399.74
# ..                       ...                    ...
# 20          ELMAR NASCIMENTO              692252.08
# 51              LUIZ DE DEUS              670577.30
# 14           COLBERT MARTINS              615429.34
# 53   MARCELO GUIMARÃES FILHO              596662.13
# 16        DAVIDSON MAGALHÃES              588914.51
# 30              IRMÃO LAZARO              556576.87
# 40              JOÃO ALMEIDA              537653.65
# 71  SÉRGIO BARRADAS CARNEIRO              535460.55
# 52            LÍDICE DA MATA              522470.04
# 23       FERNANDO DE FABINHO              520025.61
# 26            FÉLIX MENDONÇA              515834.52
# 78                    VELOSO              494491.02
# 74           TONHA MAGALHÃES              489153.45
# 42            JOÃO GUALBERTO              478855.01
# 70           SEVERIANO ALVES              474039.88
# 49              LUIZ BASSUMA              467282.90
# 32              JORGE KHOURY              411754.31
# 50             LUIZ CARREIRA              379005.21
# 34           JOSEPH BANDEIRA              350596.67
# 18              EDSON DUARTE              316729.57
# 76            ULDURICO PINTO              265712.53
# 69                 RUI COSTA              240186.33
# 63      PASTOR LUCIANO BRAGA              154139.63
# 80           WALTER PINHEIRO              148287.94
# 17         EDIGAR MÃO BRANCA              125858.00
# 28        GEDDEL VIEIRA LIMA              114432.53
# 56            MILTON BARBOSA              110765.28
# 31            JAIRO CARNEIRO               77544.62
# 81        ZE CARLOS DA PESCA               15838.16
# 67          ROBINSON ALMEIDA                 201.75
#
# [83 rows x 2 columns]
